# %%
import pandas as pd
vendas_df = pd.read_excel("../Exercicio02/Vendas.xlsx")
dados_ordenados_df = vendas_df.sort_values("Produto")
dados_ordenados_df.to_csv("dados_ordenados_df.csv", index=False)
display(dados_ordenados_df)
# Out:
#     Código Venda       Data                           ID Loja  \
# 30            23 2019-01-02        Center Shopping Uberlândia
# 51            40 2019-01-02                 Shopping Eldorado
# 57            43 2019-01-02                 Shopping Eldorado
# 6              5 2019-01-02                    Shopping Barra
# 58            44 2019-01-02               Shopping Ibirapuera
# ..           ...        ...                               ...
# 19            12 2019-01-02              Shopping Midway Mall
# 10             8 2019-01-02                 Iguatemi Campinas
# 34            27 2019-01-02        Rio Mar Shopping Fortaleza
# 67            49 2019-01-02                Iguatemi Esplanada
# 11             9 2019-01-02  Shopping Center Leste Aricanduva
#
#             Produto  Quantidade  Valor Unitário  Valor Final
# 30  Bermuda Estampa           3             169          507
# 51    Bermuda Linho           1             195          195
# ...
