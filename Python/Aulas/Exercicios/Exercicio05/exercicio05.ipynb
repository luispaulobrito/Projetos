# %%
import pandas as pd
vendas_df = pd.read_excel("../Exercicio02/Vendas.xlsx")
gerentes_df = pd.read_excel("Gerentes.xlsx")
vendas_por_gerentes_df = gerentes_df.merge(vendas_df)
display(vendas_por_gerentes_df)
vendas_por_gerentes_df.to_csv("vendas_por_gerentes.csv", index=False)
# Out:
#                          ID Loja   Gerente  Código Venda       Data  \
# 0             Iguatemi Esplanada  Salvador             1 2019-01-01
# 1             Iguatemi Esplanada  Salvador             1 2019-01-01
# 2             Iguatemi Esplanada  Salvador             1 2019-01-01
# 3             Iguatemi Esplanada  Salvador            21 2019-01-02
# 4             Iguatemi Esplanada  Salvador            34 2019-01-02
# ..                           ...       ...           ...        ...
# 65  Novo Shopping Ribeirão Preto     Diana            41 2019-01-02
# 66                Rio Mar Recife       Ana            46 2019-01-02
# 67                Rio Mar Recife       Ana            46 2019-01-02
# 68                Rio Mar Recife       Ana            46 2019-01-02
# 69   Palladium Shopping Curitiba    Flavia            47 2019-01-02
#
#                    Produto  Quantidade  Valor Unitário  Valor Final
# 0           Sapato Estampa           1             358          358
# ...
