# %%
import pandas as pd
vendas_df = pd.read_excel("Vendas.xlsx")
display(vendas_df)
vendas_df['Valor Unitário'].mean()
# Out:
#     Código Venda       Data                      ID Loja         Produto  \
# 0              1 2019-01-01           Iguatemi Esplanada  Sapato Estampa
# 1              1 2019-01-01           Iguatemi Esplanada        Camiseta
# 2              1 2019-01-01           Iguatemi Esplanada   Sapato Xadrez
# 3              2 2019-01-02               Norte Shopping         Relógio
# 4              2 2019-01-02               Norte Shopping    Chinelo Liso
# ..           ...        ...                          ...             ...
# 65            47 2019-01-02  Palladium Shopping Curitiba           Short
# 66            48 2019-01-02         Shopping Midway Mall     Cueca Linho
# 67            49 2019-01-02           Iguatemi Esplanada    Terno Xadrez
# 68            49 2019-01-02           Iguatemi Esplanada     Sapato Liso
# 69            51 2019-01-02    Parque Dom Pedro Shopping  Cinto Listrado
#
#     Quantidade  Valor Unitário  Valor Final
# 0            1             358          358
# ...
